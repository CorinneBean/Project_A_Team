# %%
from sklearn.preprocessing import normalize
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
file = "../Resources/Cat_Intake_Outcome.csv"
cat_df = pd.read_csv(file)
cat_df.head(5)
# Out:
#    index_id_intake animal_id_intake  datetime_intake monthyear_intake  \
# 0            69127          A293383  3/18/2018 18:17           Mar-18
# 1            69739          A302868   6/27/2018 9:03           Jun-18
# 2           110590          A372496  6/26/2021 10:28           Jun-21
# 3            43056          A373219  7/29/2014 11:43           Jul-14
# 4             3661          A549918   5/1/2014 11:00           May-14
#
#                                    found_location      intake_type  \
# 0                6005 Walnut Hills in Austin (TX)            Stray
# 1  Pecan Creek Pkwy & Hard Rock Rd in Austin (TX)            Stray
# 2              1109 Southwood Road in Austin (TX)            Stray
# 3                                     Austin (TX)  Owner Surrender
# 4                                     Austin (TX)  Owner Surrender
#
#   intake_condition animal_type_intake sex_upon_intake age_upon_intake  ...  \
# 0             Sick                Cat   Neutered Male        15 years  ...
# 1             Aged                Cat   Spayed Female        15 years  ...
# 2           Normal                Cat   Spayed Female        18 years  ...
# 3           Normal                Cat   Spayed Female         5 years  ...
# 4           Normal                Cat   Neutered Male         4 years  ...
#
#   order_of_outcome breed_intake_subtype    main_breed_intake  \
# 0                1             Purebred              Siamese
# 1                1                  Mix  Domestic Shorthair
# 2                1                  Mix  Domestic Shorthair
# 3                1                  Mix  Domestic Shorthair
# 4                1                  Mix  Domestic Shorthair
#
#    breed_contains_pitbull sex_upon_intake_subtype   time_in_shelter  \
# 0                       N                    Male          19:27:00
# 1                       N                  Female  17 days 06:28:00
# 2                       N                  Female   2 days 03:55:00
# 3                       N                  Female   7 days 04:33:00
# 4                       N                    Male   8 days 02:07:00
#
#    days_in_shelter zipcode_intake                       longitude_intake  \
# 0                0        78723.0  -97.67646196099997,30.306264894000037
# 1               17            NaN                                    NaN
# 2                2        78704.0  -97.76571377399995,30.243651185000033
# 3                7            NaN                                    NaN
# 4                8            NaN                                    NaN
#
#    latitude_intake
# 0       63951360.0
# 1              NaN
# 2       63943945.0
# 3              NaN
# 4              NaN
#
# [5 rows x 51 columns]
