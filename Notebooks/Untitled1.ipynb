# %%
import pandas as pd

# %%
file = "../Resources/all_animals_demographics.csv"
demo_df = pd.read_csv(file)
demo_df.head(3)
# Out:
#    Unnamed: 0  index_id_intake animal_id_intake      datetime_intake  \
# 0           0            69127          A293383  2018-03-18 18:17:00
# 1           1            74120          A598657  2017-12-10 10:20:00
# 2           2            15329          A670563  2014-01-10 11:35:00
#
#   monthyear_intake                        found_location intake_type  \
# 0       March 2018      6005 Walnut Hills in Austin (TX)       Stray
# 1    December 2017  2938 Pecan Springs Rd in Austin (TX)       Stray
# 2     January 2014        5209 Cameron Rd in Austin (TX)       Stray
#
#   intake_condition animal_type_intake sex_upon_intake  ... major_city  \
# 0             Sick                Cat   Neutered Male  ...     Austin
# 1           Normal                Dog   Spayed Female  ...     Austin
# 2           Normal                Dog   Intact Female  ...     Austin
#
#           county state  population  population_density housing_units  \
# ...

# %%
# Change index to index_id
demo_df = demo_df.set_index("index_id_intake")
demo_df.head(3)
# Out:
#                  Unnamed: 0 animal_id_intake      datetime_intake  \
# index_id_intake
# 69127                     0          A293383  2018-03-18 18:17:00
# 74120                     1          A598657  2017-12-10 10:20:00
# 15329                     2          A670563  2014-01-10 11:35:00
#
#                 monthyear_intake                        found_location  \
# index_id_intake
# 69127                 March 2018      6005 Walnut Hills in Austin (TX)
# 74120              December 2017  2938 Pecan Springs Rd in Austin (TX)
# 15329               January 2014        5209 Cameron Rd in Austin (TX)
#
#                 intake_type intake_condition animal_type_intake  \
# index_id_intake
# 69127                 Stray             Sick                Cat
# 74120                 Stray           Normal                Dog
# 15329                 Stray           Normal                Dog
#
#                 sex_upon_intake age_upon_intake  ... major_city  \
# ...

# %%
demo_df = demo_df.loc[:, ~demo_df.columns.str.contains('^Unnamed')]

# %%
demo_df.dtypes
# Out:
# animal_id_intake                                      object
# datetime_intake                                       object
# monthyear_intake                                      object
# found_location                                        object
# intake_type                                           object
# intake_condition                                      object
# animal_type_intake                                    object
# sex_upon_intake                                       object
# age_upon_intake                                       object
# breed_intake                                          object
# color_intake                                          object
# age_upon_intake(days)                                  int64
# age_upon_intake(years)                               float64
# age_range_intake                                      object
# intake_month                                           int64
# ...

# %%
demo_df["population_by_gender"].apply(pd.Series)
demo_df = pd.concat([demo_df, demo_df["population_by_gender"].apply(pd.Series)],axis =1)
demo_df.head()
# Out:
#                 animal_id_intake      datetime_intake monthyear_intake  \
# index_id_intake
# 69127                    A293383  2018-03-18 18:17:00       March 2018
# 74120                    A598657  2017-12-10 10:20:00    December 2017
# 15329                    A670563  2014-01-10 11:35:00     January 2014
# 47825                    A674455  2014-03-13 12:22:00       March 2014
# 46463                    A679232  2014-05-17 16:23:00         May 2014
#
#                                        found_location      intake_type  \
# index_id_intake
# 69127                6005 Walnut Hills in Austin (TX)            Stray
# 74120            2938 Pecan Springs Rd in Austin (TX)            Stray
# 15329                  5209 Cameron Rd in Austin (TX)            Stray
# 47825               6403 Chimney Creek in Austin (TX)  Owner Surrender
# 46463                  7227 E  Hwy 290 in Austin (TX)            Stray
#
#                 intake_condition animal_type_intake sex_upon_intake  \
# ...

# %%
demo_df.dtypes
# Out:
# animal_id_intake                                     object
# datetime_intake                                      object
# monthyear_intake                                     object
# found_location                                       object
# intake_type                                          object
#                                                       ...
# median_household_income                               int64
# population_by_gender                                 object
# population_by_race                                   object
# educational_attainment_for_population_25_and_over    object
# 0                                                    object
# Length: 61, dtype: object

# %%
Population_by_gender = demo_df['population_by_gender']
Population_by_gender.head()
# Out:
# index_id_intake
# 69127    [{'key': 'Data', 'values': [{'x': 'Male', 'y':...
# 74120    [{'key': 'Data', 'values': [{'x': 'Male', 'y':...
# 15329    [{'key': 'Data', 'values': [{'x': 'Male', 'y':...
# 47825    [{'key': 'Data', 'values': [{'x': 'Male', 'y':...
# 46463    [{'key': 'Data', 'values': [{'x': 'Male', 'y':...
# Name: population_by_gender, dtype: object

# %%
Population_by_gender.str.replace(r''key': 'Data', 'values':'')
Population_by_gender.head()
# Out:
#   File "C:\Users\arroc\AppData\Local\Temp/ipykernel_24136/1764159859.py", line 1
#     Population_by_gender.str.replace(r''key': 'Data', 'values':'')
#                                           ^
# SyntaxError: invalid syntax
